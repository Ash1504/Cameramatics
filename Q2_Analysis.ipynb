# %%
import pandas as pd

# %%
df = pd.read_csv("extracted_data.csv")

# %%
df.head()
# Out:
#             taxi_group_name driver_full_name  disabled  deleted  \
# 0  Walsh, Hammond and Craig   Bruce Marshall         0        1
# 1  Walsh, Hammond and Craig     Carol Holmes         0        0
# 2  Walsh, Hammond and Craig       Jay Bailey         0        0
# 3  Walsh, Hammond and Craig      Aimee Smith         0        1
# 4  Walsh, Hammond and Craig      Hayley Hall         0        0
#
#    vehicle_brand  experience_group  awards  endurance_score  \
# 0              7                 6       0         0.666398
# 1              9                 4       0        -1.177850
# 2             16                 6       0        -0.557925
# 3              3                 4       0        -0.787186
# 4             14                 1       0         0.518161
#
#    profitability_score  safety_adherence_score  efficiency_score  \
# 0            -0.252875                0.279009          1.892210
# 1            -1.560460               -1.211520         -0.510155
# 2             0.083300                0.596134          0.257793
# 3            -0.484124                0.966867          0.548890
# 4            -0.108167               -0.025077         -0.133834
#
#    no_of_1_star_rating  no_of_2_star_rating  no_of_3_star_rating  \
# 0                    9                   38                   40
# 1                    8                   16                   28
# 2                    5                   12                   25
# 3                    8                    8                   16
# 4                   22                   32                   53
#
#    no_of_4_star_rating  no_of_5_star_rating
# 0                   20                   22
# 1                   43                   39
# 2                   39                   26
# 3                   52                   34
# 4                   16                   13

# %%
"""
Get the drivers which are not disabled or deleted - so only active drivers
"""
active_drivers = df[(df['disabled'] == 0) & (df['deleted'] == 0)].copy()
active_drivers.drop(columns = ['disabled','deleted'], inplace=True)

# %%
"""
Normalise the ratings to a new column based on positive and negative ratings. 
Positive ratings - rating equal and above 4
Negative ratings - rating equal and below 2
Neutral ratings - 3 as the experience with the driver is neutral 
 ** may have included in the calculation as saw that there are more neutral ratings to the driver but 
"""
positive_ratings = active_drivers['no_of_4_star_rating'] + active_drivers['no_of_5_star_rating']
negative_ratings = active_drivers['no_of_1_star_rating'] + active_drivers['no_of_2_star_rating']
active_drivers['sentiment_score'] = (positive_ratings - negative_ratings) / (positive_ratings + negative_ratings)

# %%
active_drivers.head()
# Out:
#             taxi_group_name driver_full_name  vehicle_brand  experience_group  \
# 1  Walsh, Hammond and Craig     Carol Holmes              9                 4
# 2  Walsh, Hammond and Craig       Jay Bailey             16                 6
# 4  Walsh, Hammond and Craig      Hayley Hall             14                 1
# 5  Walsh, Hammond and Craig     Kerry Howard              8                 6
# 6  Walsh, Hammond and Craig       Max Harris              6                 3
#
#    awards  endurance_score  profitability_score  safety_adherence_score  \
# 1       0        -1.177850            -1.560460               -1.211520
# 2       0        -0.557925             0.083300                0.596134
# 4       0         0.518161            -0.108167               -0.025077
# 5       0         0.131069             0.406218                1.494310
# 6       0         0.510684             1.323400               -0.183761
#
#    efficiency_score  no_of_1_star_rating  no_of_2_star_rating  \
# 1         -0.510155                    8                   16
# 2          0.257793                    5                   12
# 4         -0.133834                   22                   32
# 5          0.023233                    3                    7
# 6          0.453363                   18                   22
#
#    no_of_3_star_rating  no_of_4_star_rating  no_of_5_star_rating  \
# 1                   28                   43                   39
# 2                   25                   39                   26
# 4                   53                   16                   13
# 5                   10                   54                   48
# 6                   48                   31                   23
#
#    sentiment_score
# 1         0.547170
# 2         0.585366
# 4        -0.301205
# 5         0.821429
# 6         0.148936

# %%
"""
FInding the correlation of endurance_score, profitability_score, safety_adherence_score, 
efficiency_score with the sentiment score
"""
columns_to_select = ['sentiment_score','endurance_score', 'profitability_score', 'safety_adherence_score', 'efficiency_score']
corr_data = active_drivers[columns_to_select]
correlation_matrix = corr_data.corr()
correlation_matrix.head()
# Out:
#                         sentiment_score  endurance_score  profitability_score  \
# sentiment_score                1.000000        -0.013820             0.079317
# endurance_score               -0.013820         1.000000             0.415517
# profitability_score            0.079317         0.415517             1.000000
# safety_adherence_score        -0.071492         0.231340             0.434858
# efficiency_score               0.284869         0.163782             0.374300
#
#                         safety_adherence_score  efficiency_score
# sentiment_score                      -0.071492          0.284869
# endurance_score                       0.231340          0.163782
# profitability_score                   0.434858          0.374300
# safety_adherence_score                1.000000          0.007152
# efficiency_score                      0.007152          1.000000

# %%
"""
Get the normalized weights based on the correlation data
"""
corr_endurance = -0.013820
corr_profitability = 0.079317
corr_safety_adherence_score = -0.071492
corr_efficiency_score = 0.284869

# Take absolute values
abs_corr_endurance = abs(corr_endurance)
abs_corr_profitability = abs(corr_profitability)
abs_corr_safety_adherence_score = abs(corr_safety_adherence_score)
abs_corr_efficiency_score = abs(corr_efficiency_score)

# Normalize the absolute values
total_abs_correlation = abs_corr_endurance + abs_corr_profitability + abs_corr_safety_adherence_score + abs_corr_efficiency_score

weight_endurance = abs_corr_endurance / total_abs_correlation
weight_profitability = abs_corr_profitability / total_abs_correlation
weight_safety = abs_corr_safety_adherence_score / total_abs_correlation
weight_efficiency = abs_corr_efficiency_score / total_abs_correlation

print(f"Weight for endurance_score: {weight_endurance}")
print(f"Weight for profitability_score: {weight_profitability}")
print(f"Weight for profitability_score: {weight_safety}")
print(f"Weight for profitability_score: {weight_efficiency}")
# Out:
# Weight for endurance_score: 0.030745409323289542
# Weight for profitability_score: 0.17645684741645126
# Weight for profitability_score: 0.15904853859194035
# Weight for profitability_score: 0.6337492046683189

# %%
active_drivers['composite_score'] = (
    active_drivers['endurance_score'] * weight_endurance +
    active_drivers['profitability_score'] * weight_profitability +
    active_drivers['safety_adherence_score'] * weight_safety +
    active_drivers['efficiency_score'] * weight_efficiency
)

# %%
top_10_drivers = active_drivers.sort_values(by=['composite_score', 'sentiment_score'], ascending=[False, False]).head(10)
top_10_drivers = top_10_drivers.head(10).reset_index().drop(columns='index',axis=1)

# %%
"""
Noticed - all top 10 drivers are using vehicle brand 14 and have received awards as well :) 
"""
top_10_drivers.head(10)
# Out:
#                  taxi_group_name   driver_full_name  vehicle_brand  \
# 0        Payne, Wade and Barrett         Eric Jones             14
# 1                     Thomas Ltd     Yvonne Bennett             14
# 2                 Allen and Sons       Reece Taylor             14
# 3              O'Sullivan-Burton        Jamie Brown             14
# 4                   Martin-Jones          Ann Adams             14
# 5           Ward, Smith and Nash  Vincent Sanderson             14
# 6                    Long-Harris   Cameron Bartlett             14
# 7                     Burton Inc     Julian Roberts             14
# 8         Burns, Birch and Davis         Sian James             14
# 9  Graham, Thompson and Anderson        Nicola Mann             14
#
#    experience_group  awards  endurance_score  profitability_score  \
# 0                 3       1        -0.738854             0.579694
# 1                 3       1        -0.843854             0.420694
# 2                 3       1        -0.745854             0.570694
# 3                 3       1        -0.816854             0.476694
# 4                 3       1        -0.794854             0.495694
# 5                 3       1        -0.666854             0.537694
# 6                 3       1        -0.705854             0.419694
# 7                 3       1        -0.850854             0.449694
# 8                 3       1        -0.757854             0.464694
# 9                 3       1        -0.763854             0.451694
#
#    safety_adherence_score  efficiency_score  no_of_1_star_rating  \
# 0                0.425859           3.94514                    5
# 1                0.607859           3.94814                    4
# 2                0.521859           3.91914                    7
# 3                0.536859           3.94414                    8
# 4                0.512859           3.94114                    5
# 5                0.456859           3.92414                    5
# 6                0.533859           3.93514                    8
# 7                0.491859           3.93414                    7
# 8                0.579859           3.90314                    6
# 9                0.425859           3.93714                    6
#
#    no_of_2_star_rating  no_of_3_star_rating  no_of_4_star_rating  \
# 0                   19                   16                   59
# 1                   15                   15                   60
# 2                   14                   17                   60
# 3                   16                   15                   58
# 4                   13                   15                   62
# 5                   15                   15                   57
# 6                   13                   14                   62
# 7                   15                   18                   59
# 8                   17                   15                   58
# 9                   18                   16                   59
#
#    no_of_5_star_rating  sentiment_score  composite_score
# 0                   51         0.641791         2.647536
# 1                   53         0.712121         2.647099
# 2                   55         0.691176         2.644524
# 3                   55         0.649635         2.643984
# 4                   52         0.727273         2.642294
# 5                   50         0.685039         2.633960
# 6                   53         0.691176         2.631157
# 7                   53         0.671642         2.624679
# 8                   50         0.648855         2.624536
# 9                   53         0.647059         2.619111

# %%
"""
Considering experience group as well with other metrics for customer satisfaction 
 -- Guess awards were awarded to drivers having good ratings to skipping that column for this analysis
"""
columns_to_select = ['sentiment_score','endurance_score', 'profitability_score', 'safety_adherence_score', 'efficiency_score','experience_group']
corr_data = active_drivers[columns_to_select]
correlation_matrix = corr_data.corr()
correlation_matrix.head(10)
# Out:
#                         sentiment_score  endurance_score  profitability_score  \
# sentiment_score                1.000000        -0.013820             0.079317
# endurance_score               -0.013820         1.000000             0.415517
# profitability_score            0.079317         0.415517             1.000000
# safety_adherence_score        -0.071492         0.231340             0.434858
# efficiency_score               0.284869         0.163782             0.374300
# experience_group               0.024587         0.051914             0.060503
#
#                         safety_adherence_score  efficiency_score  \
# sentiment_score                      -0.071492          0.284869
# endurance_score                       0.231340          0.163782
# profitability_score                   0.434858          0.374300
# safety_adherence_score                1.000000          0.007152
# efficiency_score                      0.007152          1.000000
# experience_group                      0.043426         -0.019474
#
#                         experience_group
# sentiment_score                 0.024587
# endurance_score                 0.051914
# profitability_score             0.060503
# safety_adherence_score          0.043426
# efficiency_score               -0.019474
# experience_group                1.000000

# %%
corr_exp_group = 0.024587
abs_corr_exp_group = abs(corr_exp_group)
total_abs_correlation = total_abs_correlation + abs_corr_exp_group
weight_exp_group = abs_corr_exp_group / total_abs_correlation
active_drivers['composite_score']  = (active_drivers['composite_score'] + active_drivers['experience_group'] * weight_exp_group)

# %%
top_10_drivers = active_drivers.sort_values(by=['composite_score', 'sentiment_score'], ascending=[False, False]).head(10)
top_10_drivers = top_10_drivers.head(10).reset_index().drop(columns='index',axis=1)

# %%
top_10_drivers.head(10)
# Out:
#                  taxi_group_name   driver_full_name  vehicle_brand  \
# 0        Payne, Wade and Barrett         Eric Jones             14
# 1                     Thomas Ltd     Yvonne Bennett             14
# 2                 Allen and Sons       Reece Taylor             14
# 3              O'Sullivan-Burton        Jamie Brown             14
# 4                   Martin-Jones          Ann Adams             14
# 5           Ward, Smith and Nash  Vincent Sanderson             14
# 6                    Long-Harris   Cameron Bartlett             14
# 7                     Burton Inc     Julian Roberts             14
# 8         Burns, Birch and Davis         Sian James             14
# 9  Graham, Thompson and Anderson        Nicola Mann             14
#
#    experience_group  awards  endurance_score  profitability_score  \
# 0                 3       1        -0.738854             0.579694
# 1                 3       1        -0.843854             0.420694
# 2                 3       1        -0.745854             0.570694
# 3                 3       1        -0.816854             0.476694
# 4                 3       1        -0.794854             0.495694
# 5                 3       1        -0.666854             0.537694
# 6                 3       1        -0.705854             0.419694
# 7                 3       1        -0.850854             0.449694
# 8                 3       1        -0.757854             0.464694
# 9                 3       1        -0.763854             0.451694
#
#    safety_adherence_score  efficiency_score  no_of_1_star_rating  \
# 0                0.425859           3.94514                    5
# 1                0.607859           3.94814                    4
# 2                0.521859           3.91914                    7
# 3                0.536859           3.94414                    8
# 4                0.512859           3.94114                    5
# 5                0.456859           3.92414                    5
# 6                0.533859           3.93514                    8
# 7                0.491859           3.93414                    7
# 8                0.579859           3.90314                    6
# 9                0.425859           3.93714                    6
#
#    no_of_2_star_rating  no_of_3_star_rating  no_of_4_star_rating  \
# 0                   19                   16                   59
# 1                   15                   15                   60
# 2                   14                   17                   60
# 3                   16                   15                   58
# 4                   13                   15                   62
# 5                   15                   15                   57
# 6                   13                   14                   62
# 7                   15                   18                   59
# 8                   17                   15                   58
# 9                   18                   16                   59
#
#    no_of_5_star_rating  sentiment_score  composite_score
# 0                   51         0.641791         2.803122
# 1                   53         0.712121         2.802685
# 2                   55         0.691176         2.800110
# 3                   55         0.649635         2.799570
# 4                   52         0.727273         2.797880
# 5                   50         0.685039         2.789546
# 6                   53         0.691176         2.786743
# 7                   53         0.671642         2.780265
# 8                   50         0.648855         2.780122
# 9                   53         0.647059         2.774697

# %%
"""
Using Linear Regression Algo to get weights
"""
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

features = active_drivers[['endurance_score', 'profitability_score', 'safety_adherence_score', 'efficiency_score']]
targets = active_drivers['sentiment_score']

# Train-Test Split
X_train, X_test, y_train, y_test = train_test_split(features, targets, test_size=0.2, random_state=42)

# Train a Regression Model
model = LinearRegression()
model.fit(X_train, y_train)

# Evaluate the Model
y_pred = model.predict(X_test)

# Extract Coefficients as Weights
weights = model.coef_

# Apply Weights to Calculate Overall Score
active_drivers['overall_score'] = active_drivers.apply(lambda row: sum(row[metric] * weight for metric, weight in zip(features.columns, weights)), axis=1)

# %%
top_10_drivers = active_drivers.sort_values(by=['overall_score', 'sentiment_score'], ascending=[False, False]).head(10)
top_10_drivers = top_10_drivers.head(10).reset_index().drop(columns='index',axis=1)
top_10_drivers.head(10)
# Out:
#                  taxi_group_name   driver_full_name  vehicle_brand  \
# 0        Payne, Wade and Barrett         Eric Jones             14
# 1  Graham, Thompson and Anderson        Nicola Mann             14
# 2                     Burton Inc     Julian Roberts             14
# 3                   Martin-Jones          Ann Adams             14
# 4              O'Sullivan-Burton        Jamie Brown             14
# 5                     Thomas Ltd     Yvonne Bennett             14
# 6                        Fox Inc       Louise Jones             14
# 7                   Reynolds Inc        Reece Lewis             14
# 8           Ward, Smith and Nash  Vincent Sanderson             14
# 9                 Allen and Sons       Reece Taylor             14
#
#    experience_group  awards  endurance_score  profitability_score  \
# 0                 3       1        -0.738854             0.579694
# 1                 3       1        -0.763854             0.451694
# 2                 3       1        -0.850854             0.449694
# 3                 3       1        -0.794854             0.495694
# 4                 3       1        -0.816854             0.476694
# 5                 3       1        -0.843854             0.420694
# 6                 3       1        -0.798854             0.453694
# 7                 3       1        -0.840854             0.455694
# 8                 3       1        -0.666854             0.537694
# 9                 3       1        -0.745854             0.570694
#
#    safety_adherence_score  efficiency_score  no_of_1_star_rating  \
# 0                0.425859           3.94514                    5
# 1                0.425859           3.93714                    6
# 2                0.491859           3.93414                    7
# 3                0.512859           3.94114                    5
# 4                0.536859           3.94414                    8
# 5                0.607859           3.94814                    4
# 6                0.477859           3.91614                    6
# 7                0.441859           3.89614                    5
# 8                0.456859           3.92414                    5
# 9                0.521859           3.91914                    7
#
#    no_of_2_star_rating  no_of_3_star_rating  no_of_4_star_rating  \
# 0                   19                   16                   59
# 1                   18                   16                   59
# 2                   15                   18                   59
# 3                   13                   15                   62
# 4                   16                   15                   58
# 5                   15                   15                   60
# 6                   13                   12                   61
# 7                   15                   16                   59
# 8                   15                   15                   57
# 9                   14                   17                   60
#
#    no_of_5_star_rating  sentiment_score  composite_score  overall_score
# 0                   51         0.641791         2.803122       0.565690
# 1                   53         0.647059         2.774697       0.563483
# 2                   53         0.671642         2.780265       0.563106
# 3                   52         0.727273         2.797880       0.562431
# 4                   55         0.649635         2.799570       0.562346
# 5                   53         0.712121         2.802685       0.560360
# 6                   53         0.714286         2.768936       0.559698
# 7                   51         0.692308         2.749597       0.559364
# 8                   50         0.685039         2.789546       0.559075
# 9                   55         0.691176         2.800110       0.558718
